# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
#*   Step 1 - Climate Analysis and Exploration
#*      To begin, use Python and SQLAlchemy to do basic climate analysis and data exploration of your climate database. All of the following analysis should be completed using SQLAlchemy ORM queries, Pandas, and Matplotlib.
#*      Use the provided [starter notebook](climate_starter.ipynb) and [hawaii.sqlite](Resources/hawaii.sqlite) files to complete your climate analysis and data exploration.
#*      Choose a start date and end date for your trip. Make sure that your vacation range is approximately 3-15 days total.
#*         Trip start date 3/31/2018 - 4/14/2018 to celebrate 50th Birthday!!!
#*      Use SQLAlchemy `create_engine` to connect to your sqlite database.
#*      Use SQLAlchemy `automap_base()` to reflect your tables into classes and save a reference to those classes called `Station` and `Measurement`.

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
#  Inspect Tables
#  We will use "inspect" to learn more ablout the tables (measurement, stations).
#  We will save classes of each table.

# %%
#inspect measurement table schema
inspector = inspect(engine)
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Measurements -
#    An inspection of the .csv file shows that following columns and data for Measurements, 
#    which correlates with the table schema data above.
#    The file begins with data from 1/1/2010 through 8/23/2017 containing 19550 daily records.
#    This is also validated by the the total, first adn last date queries found below. 
#
#    station        date        prcp     tobs
#    USC00519397    1/1/2010    0.08     65

# %%
#inspect station table schema
inspector = inspect(engine)
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Stations -
#    An inspection of the .csv file shows that following columns and data 
#    for stations, which correlates with the table schema data above.
#    The file has 9 records for the various stations across the Hawaiian islands.
#
#    station       name                    latitude        longitude     elevation
#    USC00519397   WAIKIKI 717.2, HI US    21.2716         -157.8168     3

# %%
# Use the session to query Demographics table and display the first 5 locations
for row in session.query(Measurement, Measurement.date).limit(10).all():
    print(row)
# Out:
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B161A0588>, '2010-01-01')
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B161A0408>, '2010-01-02')
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B161A0148>, '2010-01-03')
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B161A0288>, '2010-01-04')
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B1613B748>, '2010-01-06')
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B1613B308>, '2010-01-07')
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B1613B348>, '2010-01-08')
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B1613BE48>, '2010-01-09')
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B1613B9C8>, '2010-01-10')
# (<sqlalchemy.ext.automap.measurement object at 0x0000028B1613BE88>, '2010-01-11')

# %%
# Hints: Look into counting and grouping operations in SQLAlchemy
dates = session.query(Measurement).group_by(Measurement.date).count()
print(dates)
# Out:
# 2792

# %%
# selecting 5 rows from measurement table to review data
engine.execute('SELECT * FROM measurement LIMIT 5').fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65.0),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63.0),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74.0),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76.0),
#  (5, 'USC00519397', '2010-01-06', None, 73.0)]

# %%
# Total dates
session.query(func.count(Measurement.date)).all()
# Out:
# [(19550)]

# %%
# First Date
session.query(Measurement.date).order_by(Measurement.date).first()
# Out:
# ('2010-01-01')

# %%
# Rubric - ✓ Gets the correct results for the last year of data (note that the last day in the dataset is 8/23/2017) 
session.query(Measurement.date).order_by(Measurement.date.desc()).first()
# Out:
# ('2017-08-23')

# %%
# Use the session to query Demographics table and display the first 5 locations
for row in session.query(Station, Station.station).limit(10).all():
    print(row)
# Out:
# (<sqlalchemy.ext.automap.station object at 0x0000028B161D5288>, 'USC00519397')
# (<sqlalchemy.ext.automap.station object at 0x0000028B161D5748>, 'USC00513117')
# (<sqlalchemy.ext.automap.station object at 0x0000028B161D5DC8>, 'USC00514830')
# (<sqlalchemy.ext.automap.station object at 0x0000028B161D5F48>, 'USC00517948')
# (<sqlalchemy.ext.automap.station object at 0x0000028B161D5E88>, 'USC00518838')
# (<sqlalchemy.ext.automap.station object at 0x0000028B161D5D08>, 'USC00519523')
# (<sqlalchemy.ext.automap.station object at 0x0000028B161D5188>, 'USC00519281')
# (<sqlalchemy.ext.automap.station object at 0x0000028B161D53C8>, 'USC00511918')
# (<sqlalchemy.ext.automap.station object at 0x0000028B161D5248>, 'USC00516128')

# %%
# Hints: Look into counting and grouping operations in SQLAlchemy
stations = session.query(Station).group_by(Station.station).count()
print(stations)
# Out:
# 9

# %%
# selecting 5 rows from station table station to review data
engine.execute('SELECT * FROM station LIMIT 5').fetchall()
# Out:
# [(1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (2, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (3, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (4, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (5, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6)]

# %%
#  Choose a start date and end date for your trip. Make sure that your vacation range is approximately 3-15 days total.
#     Trip start date 4/01/2017 - 04/03/2017.
engine.execute ('SELECT * \
                   FROM measurement \
                  WHERE date BETWEEN "2017-04-01" AND "2017-04-03" ').fetchall()
# Out:
# [(2585, 'USC00519397', '2017-04-01', 0.0, 76.0),
#  (2586, 'USC00519397', '2017-04-02', 0.0, 76.0),
#  (2587, 'USC00519397', '2017-04-03', 0.0, 77.0),
#  (5312, 'USC00513117', '2017-04-01', 0.0, 76.0),
#  (5313, 'USC00513117', '2017-04-02', 0.0, 74.0),
#  (5314, 'USC00513117', '2017-04-03', 0.08, 73.0),
#  (7514, 'USC00514830', '2017-04-01', 0.0, 78.0),
#  (7515, 'USC00514830', '2017-04-02', 0.0, 77.0),
#  (7516, 'USC00514830', '2017-04-03', 0.09, 77.0),
#  (8953, 'USC00517948', '2017-04-03', None, 75.0),
#  (12055, 'USC00519523', '2017-04-01', 0.0, 80.0),
#  (12056, 'USC00519523', '2017-04-02', 0.0, 79.0),
#  (12057, 'USC00519523', '2017-04-03', 0.0, 76.0),
#  (14829, 'USC00519281', '2017-04-01', 0.21, 74.0),
#  (14830, 'USC00519281', '2017-04-02', 0.0, 75.0),
#  (14831, 'USC00519281', '2017-04-03', 0.26, 70.0),
#  (19414, 'USC00516128', '2017-04-01', 0.2, 69.0),
#  (19415, 'USC00516128', '2017-04-02', 0.0, 71.0),
#  (19416, 'USC00516128', '2017-04-03', 0.23, 73.0)]

# %% [markdown]
# ### Precipitation Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
# Calculate the date 1 year ago from the last data point in the database
# Perform a query to retrieve the data and precipitation scores
# Save the query results as a Pandas DataFrame and set the index to the date column
# Sort the dataframe by date
# Use Pandas Plotting with Matplotlib to plot the data

# %%
#connect to database
session = Session(engine)

# %%
# Calculate the date 1 year ago from the last data point in the database

# get last date in measurement table and put in variable
last_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
print(last_date)
# Out:
# ('2017-08-23',)

# %%
# Calculate the date 1 year ago from the last data point in the database

# Gets most recent date in the measurement table and puts it in a date timestamp format
for date in last_date:
    most_recent_date = last_date.date

most_recent_date = dt.datetime.strptime(most_recent_date, "%Y-%m-%d")
print(most_recent_date)
# Out:
# 2017-08-23 00:00:00

# %%
# Calculate the date 1 year ago from the most recent date in the measurement table
last_date_minus365 = most_recent_date - dt.timedelta(days=365)
print(last_date_minus365)
# Out:
# 2016-08-23 00:00:00

# %%
# Perform a query to retrieve the data and precipitation scores

#sel = [Measurement.station, 
#       Measurement.date, 
#       Measurement.prcp, 
#       Measurement.tobs]
#last_years_prcp = session.query(*sel).\
#    filter(Measurement.date >= last_date_minus365.\
#    order_by(Measurement.station, Measurement.date).all()
#print(last_years_prcp)

last_years_prcp = session.query(Measurement.date, Measurement.prcp).\
    filter(Measurement.date >= last_date_minus365).\
    order_by(Measurement.date).all()
last_years_prcp

# Uncomment to see list in ravel form
# ly_prcp = list(np.ravel(last_years_prcp))
# Out:
# [('2016-08-24', 0.08),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 2.28),
#  ('2016-08-24', None),
#  ('2016-08-24', 1.22),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 1.45),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.21),
#  ('2016-08-25', 0.06),
#  ('2016-08-25', 0.11),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.03),
#  ('2016-08-26', 0.02),
#  ('2016-08-26', 0.04),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.01),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.18),
#  ('2016-08-27', 0.02),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.12),
#  ('2016-08-27', None),
#  ('2016-08-28', 0.01),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.6),
#  ('2016-08-28', 2.07),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.17),
#  ('2016-08-29', 0.04),
#  ('2016-08-29', None),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.35),
#  ('2016-08-29', 0.9),
#  ('2016-08-30', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
#df = pd.DataFrame(recent_prcp_data).dropna()

lyp_df = pd.DataFrame(last_years_prcp)
lyp_df.count()
# Out:
# date    2223
# prcp    2015
# dtype: int64

# %%
lyp_df.head(5)
# Out:
#          date  prcp
# 0  2016-08-24  0.08
# 1  2016-08-24  2.15
# 2  2016-08-24  2.28
# 3  2016-08-24   NaN
# 4  2016-08-24  1.22

# %%
lyp_df = pd.DataFrame(last_years_prcp).dropna()
lyp_df.count()
# Out:
# date    2015
# prcp    2015
# dtype: int64

# %%
# Rubric - # Rubric - ✓ Gets the correct results for the last year of data (note that the last day in the dataset is 8/23/2017) 
lyp_df.head(5)
# Out:
#          date  prcp
# 0  2016-08-24  0.08
# 1  2016-08-24  2.15
# 2  2016-08-24  2.28
# 4  2016-08-24  1.22
# 5  2016-08-24  2.15

# %%
#set index
lyp_df.set_index('date', inplace = True)
lyp_df.head(5)
# Out:
#             prcp
# date
# 2016-08-24  0.08
# 2016-08-24  2.15
# 2016-08-24  2.28
# 2016-08-24  1.22
# 2016-08-24  2.15

# %%
# Rubric - ✓ Sorts the dataframe by date
lyp_df = lyp_df.sort_values(by = 'date')
lyp_df.head(50)
# Out:
#             prcp
# date
# 2016-08-24  0.08
# 2016-08-24  2.15
# 2016-08-24  2.28
# 2016-08-24  1.22
# 2016-08-24  2.15
# 2016-08-24  1.45
# 2016-08-25  0.06
# 2016-08-25  0.21
# 2016-08-25  0.00
# 2016-08-25  0.11
# 2016-08-25  0.08
# 2016-08-25  0.08
# 2016-08-25  0.00
# 2016-08-26  0.00
# 2016-08-26  0.03
# 2016-08-26  0.02
# 2016-08-26  0.04
# 2016-08-26  0.00
# 2016-08-26  0.01
# 2016-08-27  0.00
# 2016-08-27  0.18
# 2016-08-27  0.02
# 2016-08-27  0.00
# 2016-08-27  0.12
# 2016-08-28  0.60
# 2016-08-28  0.14
# 2016-08-28  2.07
# 2016-08-28  0.14
# 2016-08-28  0.01
# 2016-08-28  0.14
# 2016-08-29  0.35
# 2016-08-29  0.00
# 2016-08-29  0.90
# 2016-08-29  0.17
# 2016-08-29  0.00
# 2016-08-29  0.04
# 2016-08-30  0.00
# 2016-08-30  0.00
# 2016-08-30  0.02
# 2016-08-30  0.00
# 2016-08-30  0.00
# 2016-08-30  0.05
# 2016-08-31  2.46
# 2016-08-31  0.24
# 2016-08-31  0.13
# 2016-08-31  0.10
# 2016-08-31  0.25
# 2016-09-01  0.00
# 2016-09-01  0.00
# 2016-09-01  0.00

# %%
# Rubric - ✓ Makes a plot using pandas with ​date​ as the x and precipitation​ as the y variables 

#plot data
fig, ax = plt.subplots(figsize = (12, 6))
lyp_df.plot(ax = ax, x_compat = True)
#set title and labels
ax.set_xlabel('Date',fontsize=14, weight='bold')
ax.set_ylabel('Precipitation (inches)',fontsize=14, weight='bold')
ax.set_title("Hawaii Precipitation - 08.23.16 to 08.23.17",fontsize=20, weight='bold')
plt.xticks(rotation='0')
plt.legend(bbox_to_anchor=(0.97, 0.96))
#save figure
plt.savefig("Images/output_rsl1_precipitation.png")
#plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ![precipitation](Images/precipitation.png)

# %%
### Station Analysis

#Design a query to calculate the total number of stations.
#--  Design a query to find the most active stations.
#--    List the stations and observation counts in descending order.
#--    Which station has the highest number of observations?
#    Hint: You may need to use functions such as `func.min`, `func.max`, `func.avg`, and `func.count` in your queries.

#  Design a query to retrieve the last 12 months of temperature observation data (tobs).
#    Filter by the station with the highest number of observations.
#    Plot the results as a histogram with `bins=12`.

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
lyp_df.describe()
# Out:
#               prcp
# count  2015.000000
# mean      0.176462
# std       0.460288
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %% [markdown]
# ![describe](Images/describe.png)

# %%
# Rubric - ✓ Correctly outputs the number of stations in the dataset (9) 
# Design a query to show how many stations are available in this dataset?
# Not sure what "this data set is" means --- the stations table or the measurement table
# Will run first against station table which already has a distinct list of stations being that it is a reference table
stations_tbl = session.query(Station).group_by(Station.station).count()
print(stations_tbl)
# Out:
# 9

# %%
# Rubric - ✓ Correctly outputs the number of stations in the dataset (9) 
# Design a query to show how many stations are available in this dataset?
# Not sure what "this data set is" means --- the stations table or the measurement table
# Will run first against station table which already has a distinct list of stations being that it is a reference table
# This should be equal or lessor to the count from hte above station reference table.
# In this case it is equal to stations.  If it was less that means a station is not reporting any measurements.
measurements_tbl = session.query(Measurement.station).group_by(Measurement).distinct()
measurements_tbl.count()
# Out:
# 9

# %%
# Rubric - ✓ Correctly finds the most active station by using count (USC00519281) 
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
station_counts_df=pd.DataFrame(session.query(Measurement.station, func.count(Measurement.station).label('count')).\
                                  group_by(Measurement.station).\
                                  order_by('count').all(),columns=["Station","Number_of_Measurements"])
station_counts_df
station_ord_desc_df = station_counts_df.sort_values(by = 'Number_of_Measurements',ascending=False)

most_active_station_df = station_ord_desc_df
most_active_station_df
# Out:
#        Station  Number_of_Measurements
# 8  USC00519281                    2772
# 7  USC00519397                    2724
# 6  USC00513117                    2709
# 5  USC00519523                    2669
# 4  USC00516128                    2612
# 3  USC00514830                    2202
# 2  USC00511918                    1979
# 1  USC00517948                    1372
# 0  USC00518838                     511

# %%
# Rubric - ✓ Correctly finds the most active station by using count (USC00519281) 
# This displays the sole station that is most active vs above shows the all stations in desc order for activity
# Choose the station with the highest number of temperature observations.
mac_station_df = (most_active_station_df[most_active_station_df.Number_of_Measurements == most_active_station_df.Number_of_Measurements.max()]) 
mac_station_df
# Out:
#        Station  Number_of_Measurements
# 8  USC00519281                    2772

# %%
# Rubric - ✓ Gets the min, max, and average temperatures for the most active station (USC00519281) 
# Gets the min, max, and average temperatures for the most active station (USC00519281) 
mac_station1_df = 'USC00519281'
summary_temps = session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
    filter(Measurement.station == mac_station1_df).all()
print(f"Lowest Temperature: {summary_temps[0][0]} Fahrenheit")
print(f"Highest Temperature: {summary_temps[0][1]} Fahrenheit")
print(f"Average Temperature: {round(summary_temps[0][2], 2)} Fahrenheit")
# Out:
# Lowest Temperature: 54.0 Fahrenheit
# Highest Temperature: 85.0 Fahrenheit
# Average Temperature: 71.66 Fahrenheit

# %%
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

#lyp_station = session.query(Measurement.station,Measurement.date, Measurement.prcp).\
#    filter(Measurement.station == 'USC00519281'),\
#    filter(Measurement.date >= last_date_minus365).\
#    order_by(Measurement.date).all()
#lyp_station

lyp_station_df = pd.DataFrame(session.query(Measurement.date, Measurement.tobs). \
               filter(Measurement.station == mac_station1_df).\
               filter(Measurement.date >= last_date_minus365).all())
lyp_station_df.head()
# Out:
#          date  tobs
# 0  2016-08-24  77.0
# 1  2016-08-25  80.0
# 2  2016-08-26  80.0
# 3  2016-08-27  75.0
# 4  2016-08-28  73.0

# %%
# Rubric - ✓ Correctly plots a histogram for the last year of data using tobs as the column to count. 

#index by date
lyp_station_df.set_index('date', inplace = True)
#plot histogram
fig, ax = plt.subplots()
lyp_station_df.plot.hist(bins = 12, ax = ax)
#set labels
ax.set_xlabel('Temperature (Fahrenheit)',fontsize=11, weight='bold')
ax.set_ylabel('Frequency',fontsize=11, weight='bold')
ax.set_title('Temperature vs Frequency - 08.23.16 - 08.23.17',fontsize=14, weight='bold')
plt.xticks(rotation='0', horizontalalignment='center')
#save figure
plt.savefig("Images/output_rsl2_temp.png")
#plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ![precipitation](Images/station-histogram.png)

# %% [markdown]
# ## Optional Challenge Assignment - Trip Temperature Analysis

# %%
# Rubric
### Temperature Analysis
# The starter notebook contains a function called `calc_temps` that will accept a start date and end date in the format `%Y-%m-%d` and return the minimum, average, and maximum temperatures for that range of dates.
# Use the `calc_temps` function to calculate the min, avg, and max temperatures for your trip using the matching dates from the previous year (i.e., use "2017-01-01" if your trip start date was "2018-01-01").
# Plot the min, avg, and max temperature from your previous query as a bar chart.
#   Use the average temperature as the bar height.
#   Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr).

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Rubric - ✓ Uses the calc_temps function to get the min, max, and average temperatures for a date range of their choosing 

# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
trip_temps = calc_temps('2016-04-01', '2016-04-03')

print(f"Lowest Temperature: {trip_temps[0][0]} Fahrenheit")
print(f"Average Temperature: {round(trip_temps[0][1], 2)} Fahrenheit")
print(f"Highest Temperature: {trip_temps[0][2]} Fahrenheit")
# Out:
# Lowest Temperature: 68.0 Fahrenheit
# Average Temperature: 73.58 Fahrenheit
# Highest Temperature: 78.0 Fahrenheit

# %%
# Rubric - ✓ Uses the calculated temperatures to generate a bar chart with an error bar. 

# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
#bar (tmax - tmin)
avg_temps = trip_temps[0][1]
pk_to_pk  = trip_temps[0][2] - trip_temps[0][0]

#plot figure
fig, ax = plt.subplots(figsize = (3,6 ))
plt.bar(1, avg_temps, yerr = pk_to_pk/2, width = 0.5)
#set labels
ax.set_xticks([1])
ax.set_xticklabels([""])
ax.set_title('Trip Average Temp',fontsize=14, weight='bold')
ax.set_ylabel('Temperature (Fahrenheit)',fontsize=12, weight='bold')
plt.ylim(60)
#save fig
plt.savefig("Images/output_rsl3_temp_bar.png")
#show figure
plt.tight_layout()
plt.show()

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

# %% [markdown]
# ## Optional Challenge Assignment - Daily Rainfall Average

# %%
### Daily Rainfall Average ---- Readme

#* Calculate the rainfall per weather station using the previous year's matching dates.
#* Calculate the daily normals. Normals are the averages for the min, avg, and max temperatures.
#* You are provided with a function called `daily_normals` that will calculate the daily normals for a specific date. This date string will be in the format `%m-%d`. Be sure to use all historic tobs that match that date string.
#* Create a list of dates for your trip in the format `%m-%d`. Use the `daily_normals` function to calculate the normals for each date string and append the results to a list.
#* Load the list of daily normals into a Pandas DataFrame and set the index equal to the date.
#* Use Pandas to plot an area plot (`stacked=False`) for the daily normals.

# %%
#* Calculate the rainfall per weather station using the previous year's matching dates.

# %%
### Daily Rainfall Average ---- Starter Code

# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`
# Set the start and end date of the trip
# Use the start and end date to create a range of dates
# Strip off the year and save a list of %m-%d strings
# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`
# Set the start and end date of the trip
# Use the start and end date to create a range of dates
# Stip off the year and save a list of %m-%d strings
# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
